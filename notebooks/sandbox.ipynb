# %% [markdown]
# # Phase I: Exploration

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
tf.__version__
# Out:
# 2022-08-02 12:52:17.088249: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2022-08-02 12:52:17.115920: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-02 12:52:17.115958: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# '2.9.1'

# %%
tf.random.set_seed(42)

# %%
import numpy as np
np.__version__
# Out:
# '1.23.1'

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib as mpl
mpl.rcParams['figure.figsize'] = (20, 8)
mpl.rcParams['axes.titlesize'] = 24
mpl.rcParams['axes.labelsize'] = 20

# %%
# https://github.com/AndreasMadsen/python-lrcurve
# !pip install -q lrcurve

# %%
from lrcurve import KerasLearningCurve

# %% [markdown]
# # Step 1: Loading and exploring our data set

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/openknowledge/mlops-data2day/main/data/reference.csv', delimiter=';')

# %%
df.head()
# Out:
#    training        age  emergency_breaking  braking_distance       power  \
# 0         0  41.951100                   0         40.933328  122.238329
# 1         0  24.368286                   1         44.797317  113.765298
# 2         0  18.314649                   1         41.587241  143.427269
# 3         0  51.265254                   1         47.266716  111.578133
# 4         0  23.578861                   0         42.835319  145.994235
#
#         miles      risk group_name  group
# 0   98.509765  3.715019       high      0
# 1   46.324178  2.432928     medium      1
# 2   76.862968  4.064888       high      0
# 3  102.697069  5.102777       high      0
# 4   63.690055  3.724353       high      0

# %%
df.describe()
# Out:
#           training          age  emergency_breaking  braking_distance  \
# count  1500.000000  1500.000000         1500.000000       1500.000000
# mean      0.210000    35.146663            0.394000         39.903294
# std       0.407444    12.765348            0.488798          4.781834
# min       0.000000    15.949545            0.000000         24.368993
# 25%       0.000000    25.141921            0.000000         36.733165
# 50%       0.000000    32.714683            0.000000         39.867888
# 75%       0.000000    42.633629            1.000000         42.938777
# max       1.000000    86.213394            1.000000         56.463472
#
#              power        miles         risk        group
# count  1500.000000  1500.000000  1500.000000  1500.000000
# mean    134.888089    80.965668     2.181697     0.900000
# std      35.048570    25.496752     2.482389     0.815543
# min      38.246253    18.796953    -5.274407     0.000000
# 25%     110.008660    62.666195     0.708686     0.000000
# 50%     131.055019    77.094819     2.392071     1.000000
# 75%     157.319959    95.568682     3.867287     2.000000
# max     285.750164   211.807417    10.358000     2.000000

# %%
import seaborn as sns

# %%
labels = ["High Risk", "Medium Risk", "Low Risk"]
markers = ['v', 'd', '^']
# colors = ['#FF8080', '#FFFF80', '#8080FF']
colors = ['#FF0000', '#FFFF00', '#0000FF']

# %%
features = ['training', 'age', 'emergency_breaking', 'braking_distance', 'power', 'miles', 'risk']

# %%
sns.pairplot(df, 
             kind="scatter", 
             diag_kind="kde",
             corner=True, 
             hue='group_name',
             hue_order = ['high', 'medium', 'low'],
             palette=colors, 
             markers=markers,
             vars=features);

# %%
plt.figure(figsize=(10, 10))

cm = df.corr()
cm3 = cm.iloc[:len(features), :len(features)]

hm = sns.heatmap(cm3,
                cbar=True,
                annot=True,
                square=True,
                cmap='Blues', 
                fmt='.2f',
                yticklabels=features,
                xticklabels=features)

# %% [markdown]
# # Step 2: Training a neural network

# %%
y = df['group'].values
np.unique(y, return_counts=True)
# Out:
# (array([0, 1, 2]), array([581, 488, 431]))

# %%
# df.columns

# %%
X = df.drop(['risk', 'group', 'group_name'], axis='columns').values
# simplify to 2 dimensions to make this more interpretable
# X = df[['age', 'power']].values
X.shape, y.shape
# Out:
# ((1500, 6), (1500,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=21, stratify=y)
X_train.shape, X_val.shape, y_train.shape, y_val.shape
# Out:
# ((1200, 6), (300, 6), (1200,), (300,))

# %% [markdown]
# ## Normalization
#
# https://www.tensorflow.org/api_docs/python/tf/keras/layers/Normalization

# %%
normalizer = tf.keras.layers.Normalization(axis=-1)

# %%
normalizer.adapt(X_train)
# Out:
# 2022-08-02 12:52:26.186721: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-08-02 12:52:26.186900: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-08-02 12:52:26.186934: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (DESKTOP-BEN73DP): /proc/driver/nvidia/version does not exist
# 2022-08-02 12:52:26.188309: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
X_train.mean(axis=0), X_train.std(axis=0)
# Out:
# (array([  0.21916667,  34.9826181 ,   0.38916667,  39.93096172,
#         136.06711555,  81.1859176 ]),
#  array([ 0.41368181, 12.77030533,  0.48756125,  4.72455593, 35.09912945,
#         25.88207936]))

# %%
normalizer.weights
# Out:
# [<tf.Variable 'mean:0' shape=(6,) dtype=float32, numpy=
#  array([  0.2191667 ,  34.98261   ,   0.38916662,  39.93096   ,
#         136.06711   ,  81.18591   ], dtype=float32)>,
#  <tf.Variable 'variance:0' shape=(6,) dtype=float32, numpy=
#  array([1.7113262e-01, 1.6308067e+02, 2.3771599e-01, 2.2321430e+01,
#         1.2319493e+03, 6.6988196e+02], dtype=float32)>,
#  <tf.Variable 'count:0' shape=() dtype=int64, numpy=1200>]

# %%
normalizer.mean, np.sqrt(normalizer.variance)
# Out:
# (<tf.Tensor: shape=(1, 6), dtype=float32, numpy=
#  array([[  0.2191667 ,  34.98261   ,   0.38916662,  39.93096   ,
#          136.06711   ,  81.18591   ]], dtype=float32)>,
#  array([[ 0.4136818 , 12.770305  ,  0.48756126,  4.724556  , 35.099136  ,
#          25.882078  ]], dtype=float32))

# %%
from tensorflow.keras.layers import InputLayer, Dense, Dropout, \
                                    BatchNormalization, Activation

num_features = X.shape[1]
dropout = 0.7
model = tf.keras.Sequential()

model.add(InputLayer(name='input', input_shape=(num_features,)))
model.add(normalizer)

model.add(Dense(100, name='hidden1'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Dense(100, name='hidden2'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Dense(100, name='hidden3'))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(Dropout(dropout))

model.add(Dense(name='output', units=3, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization (Normalizatio  (None, 6)                13
#  n)
#
#  hidden1 (Dense)             (None, 100)               700
#
#  activation (Activation)     (None, 100)               0
#
#  batch_normalization (BatchN  (None, 100)              400
#  ormalization)
#
#  dropout (Dropout)           (None, 100)               0
#
#  hidden2 (Dense)             (None, 100)               10100
#
#  activation_1 (Activation)   (None, 100)               0
#
#  batch_normalization_1 (Batc  (None, 100)              400
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  hidden3 (Dense)             (None, 100)               10100
#
#  activation_2 (Activation)   (None, 100)               0
#
#  batch_normalization_2 (Batc  (None, 100)              400
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 100)               0
#
#  output (Dense)              (None, 3)                 303
#
# =================================================================
# Total params: 22,416
# Trainable params: 21,803
# Non-trainable params: 613
# _________________________________________________________________

# %%
# %%time 

BATCH_SIZE = 32
# BATCH_SIZE = 64
EPOCHS = 50

model.compile(loss='sparse_categorical_crossentropy',
             optimizer='adam',
             metrics=['accuracy'])

history = model.fit(X_train, y_train,
                    validation_data=(X_val, y_val),
                    epochs=EPOCHS, 
                    batch_size=BATCH_SIZE, 
                    callbacks=[KerasLearningCurve()],
                    verbose=0)
# Out:
# <style>svg.learning-curve {
#     width: 100%;
#     shape-rendering: crispEdges;
#     font-size: 14px;
# }
#
# svg.learning-curve .tick text {
#     font-size: 14px;
#     fill: #505050;
# }
#
# svg.learning-curve .tick line {
#     stroke-width: 2;
#     stroke: #505050;
# }
#
# svg.learning-curve .background {
#     fill: #EBEBEB;
# }
#
# svg.learning-curve .facet {
#     font-size: 14px;
# }
#
# svg.learning-curve .facet-background {
#     fill: #D9D9D9;
# }
#
# svg.learning-curve path.line {
#     fill: none;
#     shape-rendering: geometricPrecision;
#     stroke-width: 1;
# }
#
# svg.learning-curve .grid line {
#     stroke: #fff;
#     stroke-width: 2;
# }
#
# svg.learning-curve .grid .minor {
#     stroke-opacity: .5;
# }
#
# svg.learning-curve .grid text {
#     display: none;
# }
#
# svg.learning-curve .axis path,
# svg.learning-curve .grid path {
#     display: none;
# }
#
# svg.learning-curve .axis.hide-axis {
#     display: none;
# }
#
# svg.learning-curve .legned rect {
#     fill: #EBEBEB;
# }
#
# svg.learning-curve .legned line {
#     stroke-width: 2;
# }
# </style><script>(function(){function r(e,n,t){function o(i,f){if(!n[i]){if(!e[i]){var c="function"==typeof require&&require;if(!f&&c)return c(i,!0);if(u)return u(i,!0);var a=new Error("Cannot find module '"+i+"'");throw a.code="MODULE_NOT_FOUND",a}var p=n[i]={exports:{}};e[i][0].call(p.exports,function(r){var n=e[i][1][r];return o(n||r)},p,p.exports,r,e,n,t)}return n[i].exports}for(var u="function"==typeof require&&require,i=0;i<t.length;i++)o(t[i]);return o}return r})()({1:[function(require,module,exports){
# window.d3 = Object.assign(
#     {},
#     // d3.select
#     // d3.selectAll
#     require('d3-selection'),
#     // .transition()
#     require('d3-transition'),
#     // d3.extent
#     require('d3-array'),
#     // d3.axisBottom
#     // d3.axisLeft
#     require('d3-axis'),
#     // d3.scaleLinear
#     // d3.scaleTime
#     require('d3-scale'),
#     // d3.line
#     require('d3-shape')
# );
#
# },{"d3-array":2,"d3-axis":3,"d3-scale":10,"d3-selection":11,"d3-shape":12,"d3-transition":16}],2:[function(require,module,exports){
# // https://d3js.org/d3-array/ v2.4.0 Copyright 2019 Mike Bostock
# (function (global, factory) {
# typeof exports === 'object' && typeof module !== 'undefined' ? factory(exports) :
# typeof define === 'function' && define.amd ? define(['exports'], factory) :
# (global = global || self, factory(global.d3 = global.d3 || {}));
# }(this, function (exports) { 'use strict';
#
# function ascending(a, b) {
#   return a < b ? -1 : a > b ? 1 : a >= b ? 0 : NaN;
# }
#
# function bisector(compare) {
#   if (compare.length === 1) compare = ascendingComparator(compare);
#   return {
#     left: function(a, x, lo, hi) {
#       if (lo == null) lo = 0;
#       if (hi == null) hi = a.length;
#       while (lo < hi) {
#         var mid = lo + hi >>> 1;
#         if (compare(a[mid], x) < 0) lo = mid + 1;
#         else hi = mid;
#       }
#       return lo;
#     },
#     right: function(a, x, lo, hi) {
#       if (lo == null) lo = 0;
#       if (hi == null) hi = a.length;
#       while (lo < hi) {
#         var mid = lo + hi >>> 1;
#         if (compare(a[mid], x) > 0) hi = mid;
#         else lo = mid + 1;
#       }
#       return lo;
#     }
#   };
# }
#
# function ascendingComparator(f) {
#   return function(d, x) {
#     return ascending(f(d), x);
#   };
# }
#
# var ascendingBisect = bisector(ascending);
# var bisectRight = ascendingBisect.right;
# var bisectLeft = ascendingBisect.left;
#
# function count(values, valueof) {
#   let count = 0;
#   if (valueof === undefined) {
#     for (let value of values) {
#       if (value != null && (value = +value) >= value) {
#         ++count;
#       }
#     }
#   } else {
#     let index = -1;
#     for (let value of values) {
#       if ((value = valueof(value, ++index, values)) != null && (value = +value) >= value) {
#         ++count;
#       }
#     }
#   }
#   return count;
# }
#
# function length(array) {
#   return array.length | 0;
# }
#
# function empty(length) {
#   return !(length > 0);
# }
#
# function arrayify(values) {
#   return typeof values !== "object" || "length" in values ? values : Array.from(values);
# }
#
# function reducer(reduce) {
#   return values => reduce(...values);
# }
#
# function cross(...values) {
#   const reduce = typeof values[values.length - 1] === "function" && reducer(values.pop());
#   values = values.map(arrayify);
#   const lengths = values.map(length);
#   const j = values.length - 1;
#   const index = new Array(j + 1).fill(0);
#   const product = [];
#   if (j < 0 || lengths.some(empty)) return product;
#   while (true) {
#     product.push(index.map((j, i) => values[i][j]));
#     let i = j;
#     while (++index[i] === lengths[i]) {
#       if (i === 0) return reduce ? product.map(reduce) : product;
#       index[i--] = 0;
#     }
#   }
# }
#
# function cumsum(values, valueof) {
#   var sum = 0, index = 0;
#   return Float64Array.from(values, valueof === undefined
#     ? v => (sum += +v || 0)
#     : v => (sum += +valueof(v, index++, values) || 0));
# }
#
# function descending(a, b) {
#   return b < a ? -1 : b > a ? 1 : b >= a ? 0 : NaN;
# }
#
# function variance(values, valueof) {
#   let count = 0;
#   let delta;
#   let mean = 0;
#   let sum = 0;
#   if (valueof === undefined) {
#     for (let value of values) {
#       if (value != null && (value = +value) >= value) {
#         delta = value - mean;
#         mean += delta / ++count;
#         sum += delta * (value - mean);
#       }
#     }
#   } else {
#     let index = -1;
#     for (let value of values) {
#       if ((value = valueof(value, ++index, values)) != null && (value = +value) >= value) {
#         delta = value - mean;
#         mean += delta / ++count;
#         sum += delta * (value - mean);
#       }
#     }
#   }
#   if (count > 1) return sum / (count - 1);
# }
#
# function deviation(values, valueof) {
#   const v = variance(values, valueof);
#   return v ? Math.sqrt(v) : v;
# }
#
# function extent(values, valueof) {
#   let min;
#   let max;
#   if (valueof === undefined) {
#     for (const value of values) {
#       if (value != null) {
#         if (min === undefined) {
#           if (value >= value) min = max = value;
#         } else {
#           if (min > value) min = value;
#           if (max < value) max = value;
#         }
#       }
#     }
#   } else {
#     let index = -1;
#     for (let value of values) {
#       if ((value = valueof(value, ++index, values)) != null) {
#         if (min === undefined) {
#           if (value >= value) min = max = value;
#         } else {
#           if (min > value) min = value;
#           if (max < value) max = value;
#         }
#       }
#     }
#   }
#   return [min, max];
# }
#
# function identity(x) {
#   return x;
# }
#
# function group(values, ...keys) {
#   return nest(values, identity, identity, keys);
# }
#
# function groups(values, ...keys) {
#   return nest(values, Array.from, identity, keys);
# }
#
# function rollup(values, reduce, ...keys) {
#   return nest(values, identity, reduce, keys);
# }
#
# function rollups(values, reduce, ...keys) {
#   return nest(values, Array.from, reduce, keys);
# }
#
# function nest(values, map, reduce, keys) {
#   return (function regroup(values, i) {
#     if (i >= keys.length) return reduce(values);
#     const groups = new Map();
#     const keyof = keys[i++];
#     let index = -1;
#     for (const value of values) {
#       const key = keyof(value, ++index, values);
#       const group = groups.get(key);
#       if (group) group.push(value);
#       else groups.set(key, [value]);
#     }
#     for (const [key, values] of groups) {
#       groups.set(key, regroup(values, i));
#     }
#     return map(groups);
#   })(values, 0);
# }
#
# var array = Array.prototype;
#
# var slice = array.slice;
#
# function constant(x) {
#   return function() {
#     return x;
#   };
# }
#
# function range(start, stop, step) {
#   start = +start, stop = +stop, step = (n = arguments.length) < 2 ? (stop = start, start = 0, 1) : n < 3 ? 1 : +step;
#
#   var i = -1,
#       n = Math.max(0, Math.ceil((stop - start) / step)) | 0,
#       range = new Array(n);
#
#   while (++i < n) {
#     range[i] = start + i * step;
#   }
#
#   return range;
# }
#
# var e10 = Math.sqrt(50),
#     e5 = Math.sqrt(10),
#     e2 = Math.sqrt(2);
#
# function ticks(start, stop, count) {
#   var reverse,
#       i = -1,
#       n,
#       ticks,
#       step;
#
#   stop = +stop, start = +start, count = +count;
#   if (start === stop && count > 0) re
# <script>  window.setupLearningCurve("44111676-fd95-48c9-a286-f888bf223087", {"id": "44111676-fd95-48c9-a286-f888bf223087", "width": 600, "height": 490, "mappings": {"val_loss": {"line": "validation", "facet": "loss"}, "val_accuracy": {"line": "validation", "facet": "accuracy"}, "loss": {"line": "train", "facet": "loss"}, "accuracy": {"line": "train", "facet": "accuracy"}}, "lineConfig": {"validation": {"name": "Validation", "color": "#00BFC4"}, "train": {"name": "Train", "color": "#F8766D"}}, "facetConfig": {"loss": {"name": "Loss", "limit": [null, null], "scale": "log10"}, "accuracy": {"name": "Accuracy", "limit": [0, 1], "scale": "linear"}}, "xAxisConfig": {"name": "Epoch", "limit": [0, 49]}});  window.appendLearningCurve("44111676-fd95-48c9-a286-f888bf223087", [[0, {"loss": 2.2110111713409424, "accuracy": 0.35749998688697815, "val_loss": 1.060775876045227, "val_accuracy": 0.3633333444595337}], [1, {"loss": 1.8188313245773315, "accuracy": 0.3883333206176758, "val_loss": 1.0023682117462158, "val_accuracy": 0.4300000071525574}], [2, {"loss": 1.7024861574172974, "accuracy": 0.40166667103767395, "val_loss": 0.9636830687522888, "val_accuracy": 0.44333332777023315}], [3, {"loss": 1.4255917072296143, "accuracy": 0.4541666805744171, "val_loss": 0.924111008644104, "val_accuracy": 0.5166666507720947}], [4, {"loss": 1.2674235105514526, "accuracy": 0.4841666519641876, "val_loss": 0.8778741359710693, "val_accuracy": 0.6166666746139526}], [5, {"loss": 1.244909644126892, "accuracy": 0.4724999964237213, "val_loss": 0.8354978561401367, "val_accuracy": 0.6433333158493042}], [6, {"loss": 1.124940037727356, "accuracy": 0.5099999904632568, "val_loss": 0.7996320724487305, "val_accuracy": 0.6733333468437195}], [7, {"loss": 1.0744068622589111, "accuracy": 0.5333333611488342, "val_loss": 0.7682362198829651, "val_accuracy": 0.6766666769981384}], [8, {"loss": 1.0211408138275146, "accuracy": 0.5408333539962769, "val_loss": 0.7329801917076111, "val_accuracy": 0.6933333277702332}], [9, {"loss": 0.946410596370697, "accuracy": 0.5566666722297668, "val_loss": 0.7113897800445557, "val_accuracy": 0.6966666579246521}], [10, {"loss": 1.0115528106689453, "accuracy": 0.5516666769981384, "val_loss": 0.6965368390083313, "val_accuracy": 0.7066666483879089}], [11, {"loss": 0.9496995806694031, "accuracy": 0.5516666769981384, "val_loss": 0.6818729043006897, "val_accuracy": 0.7099999785423279}], [12, {"loss": 0.86443692445755, "accuracy": 0.5933333039283752, "val_loss": 0.674328625202179, "val_accuracy": 0.7266666889190674}], [13, {"loss": 0.8473972082138062, "accuracy": 0.5874999761581421, "val_loss": 0.6634185910224915, "val_accuracy": 0.7333333492279053}], [14, {"loss": 0.8273791074752808, "accuracy": 0.6041666865348816, "val_loss": 0.6506696343421936, "val_accuracy": 0.7366666793823242}], [15, {"loss": 0.8061415553092957, "accuracy": 0.621666669845581, "val_loss": 0.6355863809585571, "val_accuracy": 0.7400000095367432}], [16, {"loss": 0.8080913424491882, "accuracy": 0.6208333373069763, "val_loss": 0.6282809376716614, "val_accuracy": 0.7400000095367432}], [17, {"loss": 0.8137904405593872, "accuracy": 0.5991666913032532, "val_loss": 0.6217366456985474, "val_accuracy": 0.7400000095367432}], [18, {"loss": 0.7767813801765442, "accuracy": 0.6358333230018616, "val_loss": 0.6176860332489014, "val_accuracy": 0.7433333396911621}], [19, {"loss": 0.7558000683784485, "accuracy": 0.6441666483879089, "val_loss": 0.6059596538543701, "val_accuracy": 0.7599999904632568}], [20, {"loss": 0.7462953925132751, "accuracy": 0.64083331823349, "val_loss": 0.5896307229995728, "val_accuracy": 0.7699999809265137}], [21, {"loss": 0.7479922771453857, "accuracy": 0.6416666507720947, "val_loss": 0.5821614861488342, "val_accuracy": 0.7733333110809326}], [22, {"loss": 0.7266901135444641, "accuracy": 0.653333306312561, "val_loss": 0.574898362159729, "val_accuracy": 0.7833333611488342}], [23, {"loss": 0.6966530084609985, "accuracy": 0.690833330154419, "val_loss": 0.5630595088005066, "val_accuracy": 0.78 ...
# CPU times: user 20.2 s, sys: 8.59 s, total: 28.8 s
# Wall time: 11.7 s

# %%
train_loss, train_metric = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE)
train_loss, train_metric
# Out:
# 38/38 [==============================] - 0s 2ms/step - loss: 0.3918 - accuracy: 0.8675
# (0.3917689621448517, 0.8675000071525574)

# %%
test_loss, test_metric = model.evaluate(X_val, y_val, batch_size=BATCH_SIZE)
test_loss, test_metric
# Out:
# 10/10 [==============================] - 0s 2ms/step - loss: 0.3828 - accuracy: 0.8833
# (0.3827686309814453, 0.8833333253860474)

# %%
plt.yscale('log')
plt.ylabel("loss")
plt.xlabel("epochs")
plt.title('Loss over epochs')

plt.plot(history.history['loss']);
plt.plot(history.history['val_loss']);

plt.legend(['Training', 'Validation']);

# %%
plt.ylabel("accuracy")
plt.xlabel("epochs")
plt.title('Accuracy over epochs')

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.legend(['Training', 'Validation']);

# %% [markdown]
# # Invariant Properties of Model

# %% [markdown]
# ## Accuracy range and lack of overfitting

# %%
assert train_metric > .85

# %%
assert test_metric > .85

# %%
assert train_metric - test_metric < .05

# %% [markdown]
# ## Invariants of the model itself (without using data on it)
# Could be
# * effective depth of tree (if decision tree has been used as architecture instead of NN)
# * distribution of weights
# * actual normalization
#
# **We do use these properties as we want to treat the model as a black box to make it interchangable**

# %% [markdown]
# # Invariants also useful for monitoring and analyzis - not using GT

# %%
y_pred = model.predict(X).argmax(axis=1)
y_pred.shape
# Out:
# 47/47 [==============================] - 0s 2ms/step
# (1500,)

# %%
# np.unique(y - y_pred, return_counts=True)

# %% [markdown]
# ## Distribution of Output Class

# %%
values, counts = np.unique(y_pred, return_counts=True)
values, counts
# Out:
# (array([0, 1, 2]), array([564, 494, 442]))

# %%
# equal distribution around classes expected
tolerance = 0.15
expected_count = len(X) / 3
for count in counts:
    assert count in range(int(expected_count * (1 - tolerance)), int(expected_count * (1 + tolerance)))

# %%
range(int(expected_count * (1 - tolerance)), int(expected_count * (1 + tolerance)))
# Out:
# range(425, 575)

# %% [markdown]
# ## Distribution of certainty

# %%
y_pred_probas = model.predict(X).max(axis=1)
y_pred_probas.shape
# Out:
# 47/47 [==============================] - 0s 2ms/step
# (1500,)

# %%
y_pred_probas.min(), y_pred_probas.mean(), y_pred_probas.max()
# Out:
# (0.47062495, 0.7406613, 0.9997364)

# %%
assert y_pred_probas.min() > .4

# %%
assert y_pred_probas.mean() > 0.7

# %%
assert y_pred_probas.max() > 0.99

# %% [markdown]
# ## In Monitoring both could be treated as a distribution and compared to the training reference

# %%
sns.displot(y_pred);

# %%
sns.displot(y_pred_probas);

# %% [markdown]
# ## Since at this point we just this one dataset, we can try with train vs test

# %%
y_train_pred_probas = model.predict(X_train).max(axis=1)
y_test_pred_probas = model.predict(X_val).max(axis=1)
# Out:
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step

# %%
alpha=0.1
sns.histplot(y_train_pred_probas, color='blue', bins=50, stat='percent', alpha=alpha);
sns.histplot(y_test_pred_probas, color='red', bins=50, stat='percent', alpha=alpha);

# %%
y_train_pred = model.predict(X_train).argmax(axis=1)
y_test_pred = model.predict(X_val).argmax(axis=1)
# Out:
# 38/38 [==============================] - 0s 2ms/step
# 10/10 [==============================] - 0s 2ms/step

# %%
alpha=0.1
sns.histplot(y_train_pred, color='blue', bins=50, stat='percent', alpha=alpha);
sns.histplot(y_test_pred, color='red', bins=50, stat='percent', alpha=alpha);

# %% [markdown]
# ## We can have a couple of statistical tests (more valuable in monitoring and real prod data)

# %%
from evidently.analyzers.stattests.jensenshannon import jensenshannon_stat_test
from evidently.analyzers.stattests.kl_div import kl_div_stat_test
from evidently.analyzers.stattests.ks_stattest import ks_stat_test
from evidently.analyzers.stattests.psi import psi_stat_test
from evidently.analyzers.stattests.wasserstein_distance_norm import wasserstein_stat_test

# %%
wasserstein_stat_test(y_train_pred_probas, y_test_pred_probas, 'num', threshold=None)
# Out:
# StatTestResult(drift_score=0.10149581599147939, drifted=True, actual_threshold=0.1)

# %%
ks_stat_test(y_train_pred_probas, y_test_pred_probas, 'num', threshold=None)
# Out:
# StatTestResult(drift_score=0.21831465443946194, drifted=False, actual_threshold=0.05)

# %%
psi_stat_test(pd.Series(y_train_pred_probas), pd.Series(y_test_pred_probas), 'num', threshold=None)
# Out:
# StatTestResult(drift_score=0.06337682601317271, drifted=False, actual_threshold=0.1)

# %%
jensenshannon_stat_test(pd.Series(y_train_pred), pd.Series(y_test_pred), 'cat', threshold=None)
# Out:
# StatTestResult(drift_score=0.020289585095001502, drifted=False, actual_threshold=0.1)

# %%
psi_stat_test(pd.Series(y_train_pred), pd.Series(y_test_pred), 'cat', threshold=None)
# Out:
# StatTestResult(drift_score=0.0032940205387584935, drifted=False, actual_threshold=0.1)

# %%
kl_div_stat_test(pd.Series(y_train_pred), pd.Series(y_test_pred), 'cat', threshold=None)
# Out:
# StatTestResult(drift_score=0.0016407515894181907, drifted=False, actual_threshold=0.1)

# %% [markdown]
# # Checking against "future" data
#
# Since we are simulating production data we have access to data up 36 months from now

# %%
months_from_now = 36
df_prod = pd.read_csv(f'https://raw.githubusercontent.com/openknowledge/mlops-data2day/main/data/month-{months_from_now}.csv', delimiter=';')

# %%
X_prod = df_prod.drop(['risk', 'group', 'group_name'], axis='columns').values
X.shape
# Out:
# (1500, 6)

# %%
y_prod_pred = model.predict(X_prod).argmax(axis=1)
y_prod_pred_probas = model.predict(X_prod).max(axis=1)
# Out:
# 47/47 [==============================] - 0s 2ms/step
# 47/47 [==============================] - 0s 2ms/step

# %%
alpha=0.1
sns.histplot(y_pred, color='blue', bins=50, stat='percent', alpha=alpha);
sns.histplot(y_prod_pred, color='red', bins=50, stat='percent', alpha=alpha);

# %%
result = jensenshannon_stat_test(pd.Series(y_pred), pd.Series(y_prod_pred), 'cat', threshold=None)
result
# Out:
# StatTestResult(drift_score=0.1174807429201282, drifted=True, actual_threshold=0.1)

# %%
assert result.drifted

# %%
alpha=0.1
sns.histplot(y_pred_probas, color='blue', bins=50, stat='percent', alpha=alpha);
sns.histplot(y_prod_pred_probas, color='red', bins=50, stat='percent', alpha=alpha);

# %%
# result = ks_stat_test(pd.Series(y_pred_probas), pd.Series(y_prod_pred_probas), 'num', threshold=None)
# Wasserstein seems to better reflect our intuition here 
result = wasserstein_stat_test(pd.Series(y_pred_probas), pd.Series(y_prod_pred_probas), 'num', threshold=None)
result
# Out:
# StatTestResult(drift_score=0.14972691013830372, drifted=True, actual_threshold=0.1)

# %%
assert result.drifted

# %% [markdown]
# # Pre Processing - TODO - extend to all variables
#
# Is the data feed into the model in the accepted range? Range is what has been covered by training data at all

# %%
age_range=range(10, 150)
power_range=range(50, 250)
def check_range(age, power):
    return age in age_range and power in power_range

# %%
assert check_range(age=30, power=150)

# %%
assert check_range(age=130, power=350) == False

# %% [markdown]
# # Post Processing
#
# * are we certain enough, i.e. is the proba above a certain threshold?
# * if not fall back onto very simple rule system
# * rule system should have very high bias (underfit), but should be pretty robust to changes in input

# %%
LOW_RISK = 2
MEDIUM_RISK = 1
HIGH_RISK = 0

class ClassifierBase:
    def predict(self, X):
        return np.array([ self.predict_single(x) for x in X])
    def score(self, X, y):
        n = len(y)
        correct = 0
        predictions = self.predict(X)
        for prediction, ground_truth in zip(predictions, y):
            if prediction == ground_truth:
                correct = correct + 1
        return correct / n

# %%
from random import randrange

class RandomClassifier(ClassifierBase):
    def predict_single(self, x):
        return randrange(3)
base_clf = RandomClassifier()    
base_clf.score(X, y)
# Out:
# 0.32133333333333336

# %%
# just return most frequent value might be a baseline
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1, 2]), array([465, 390, 345]))

# %%
class NaiveClassifier(ClassifierBase):
    def predict_single(self, x):
        return HIGH_RISK
base_clf = NaiveClassifier()    
base_clf.score(X, y)
# Out:
# 0.3873333333333333

# %%
df.columns
# Out:
# Index(['training', 'age', 'emergency_breaking', 'braking_distance', 'power',
#        'miles', 'risk', 'group_name', 'group'],
#       dtype='object')

# %%
class BaseLineClassifier(ClassifierBase):
    def predict_single(self, x):
        training, age, emergency_breaking, braking_distance, power, miles = x
#         print(age, power, miles)
        if training: 
            return LOW_RISK
        if age < 30:
            if power > 130:
                return HIGH_RISK
            else:
                return MEDIUM_RISK
        if age > 50:
            return HIGH_RISK
        if emergency_breaking:
            return LOW_RISK
        if miles > 50:
            return HIGH_RISK
        if miles > 30:
            return MEDIUM_RISK
        # default
        return LOW_RISK
base_clf = BaseLineClassifier() 
base_clf.score(X, y)
# Out:
# 0.586

# %% [markdown]
# ## Evaluate Lib
#
# * https://github.com/huggingface/evaluate
# * https://huggingface.co/docs/evaluate/index
# * https://twitter.com/lvwerra/status/1531652407909920769

# %%
# !pip install evaluate
# Out:
# Collecting evaluate
#   Downloading evaluate-0.2.2-py3-none-any.whl (69 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.8/69.8 kB 2.8 MB/s eta 0:00:00
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.7.1-py3-none-any.whl (141 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 141.2/141.2 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from evaluate) (21.3)
# Collecting dill
#   Using cached dill-0.3.5.1-py2.py3-none-any.whl (95 kB)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.1/212.1 kB 9.4 MB/s eta 0:00:00
# Collecting datasets>=2.0.0
#   Downloading datasets-2.4.0-py3-none-any.whl (365 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 365.7/365.7 kB 11.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from evaluate) (1.4.3)
# Requirement already satisfied: requests>=2.19.0 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from evaluate) (2.28.1)
# Collecting tqdm>=4.62.1
#   Using cached tqdm-4.64.0-py2.py3-none-any.whl (78 kB)
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.17 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from evaluate) (1.23.1)
# Collecting huggingface-hub>=0.7.0
#   Using cached huggingface_hub-0.8.1-py3-none-any.whl (101 kB)
# Collecting multiprocess
#   Downloading multiprocess-0.70.13-py38-none-any.whl (131 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.4/131.4 kB 11.0 MB/s eta 0:00:00
# Collecting pyarrow>=6.0.0
#   Downloading pyarrow-8.0.0-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.4/29.4 MB 11.4 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 12.3 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate) (4.3.0)
# Collecting filelock
#   Using cached filelock-3.7.1-py3-none-any.whl (10 kB)
# Requirement already satisfied: pyyaml>=5.1 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from huggingface-hub>=0.7.0->evaluate) (5.4.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from packaging->evaluate) (3.0.9)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from requests>=2.19.0->evaluate) (3.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from pandas->evaluate) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from pandas->evaluate) (2022.1)
# Requirement already satisfied: six>=1.5 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from python-dateutil>=2.8.1->pandas->evaluate) (1.16.0)
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.7/158.7 kB 11.1 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in /home/olli/anaconda3/envs/mlops-workshop-d2d/lib/python3.8/site-packages (from aiohttp->datasets>=2.0.0->evaluate) (21.4.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (121 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.3/121.3 kB 14.1 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.8.1-cp38-cp38-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.1/262.1 kB 12.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Installing collected packages: xxhash, tqdm, pyarrow, multidict, fsspec, frozenlist, filelock, dill, async-timeout, yarl, responses, multiprocess, huggingface-hub, aiosignal, aiohttp, datasets, evaluate
# Successfully installed aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 datasets-2.4.0 dill-0.3.5.1 evaluate-0.2.2 filelock-3.7.1 frozenlist-1.3.0 fsspec-2022.7.1 huggingface-hub-0.8.1 multidict-6.0.2 multiprocess-0.70.13 pyarrow-8.0.0 responses-0.18.0 tqdm-4.64.0 xxhash-3.0.0 yarl-1.8.1

# %%
import evaluate

# %%
accuracy = evaluate.load('accuracy')

# %%
accuracy.compute(references=y, predictions=y_pred)
# Out:
# {'accuracy': 0.8706666666666667}

# %% [markdown]
# # Saving Model

# %%
# model.save?

# %%
model.save('classifier.h5', save_format='h5')

# %%
model.save('classifier', save_format='tf')
# Out:
# INFO:tensorflow:Assets written to: classifier/assets

# %%
# !ls -l
# Out:
# total 8232
# -rw-r--r-- 1 olli olli 6728883 Aug  2 12:39 analysis.ipynb
# drwxr-xr-x 4 olli olli    4096 Aug  2 12:54 classifier
# -rw-r--r-- 1 olli olli  337864 Aug  2 12:54 classifier.h5
# -rw-r--r-- 1 olli olli  284383 Jul 29 13:02 classifier.tgz
# -rw-r--r-- 1 olli olli 1066163 Aug  2 12:53 exploration.ipynb

# %%
# !ls -l classifier/
# Out:
# total 352
# drwxr-xr-x 2 olli olli   4096 Jul 29 11:19 assets
# -rw-r--r-- 1 olli olli  22654 Aug  2 12:54 keras_metadata.pb
# -rw-r--r-- 1 olli olli 324881 Aug  2 12:54 saved_model.pb
# drwxr-xr-x 2 olli olli   4096 Aug  2 12:54 variables

# %%
# !tar czvf classifier.tgz ./classifier
# Out:
# ./classifier/
# ./classifier/keras_metadata.pb
# ./classifier/saved_model.pb
# ./classifier/assets/
# ./classifier/variables/
# ./classifier/variables/variables.index
# ./classifier/variables/variables.data-00000-of-00001

# %%
# !ls -l
# Out:
# total 8232
# -rw-r--r-- 1 olli olli 6728883 Aug  2 12:39 analysis.ipynb
# drwxr-xr-x 4 olli olli    4096 Aug  2 12:54 classifier
# -rw-r--r-- 1 olli olli  337864 Aug  2 12:54 classifier.h5
# -rw-r--r-- 1 olli olli  284450 Aug  2 12:54 classifier.tgz
# -rw-r--r-- 1 olli olli 1066163 Aug  2 12:53 exploration.ipynb
